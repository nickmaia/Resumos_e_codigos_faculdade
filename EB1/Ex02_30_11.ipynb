# %% [markdown]
# <h1 align="center">Exemplo 02</h1>

# %% [markdown]
# ---

# %% [markdown]
# ### As velocidades iniciais de uma dada reação enzimática 𝑆 → 𝑃 foram determinadas a várias concentrações de substrato. Os resultados obtidos são apresentados na Tabela a seguir:
# ![image.png](attachment:61c14ad6-76d9-4170-bd59-71b1d2bd41a8.png)
#
# ### Determine KM e Vmax pelo método gráfico de Lineweaver-Burk

# %% [markdown]
# ### Resposta:
#
# #### Foi utilizado o método gráfico de Lineweaver-Burk e para confirmação também foi utilizado o Método de Hanes.
#
# - Tabela com os dados:
#
# ![image.png](attachment:60f892f0-4fa6-4174-9f47-1ae7596da5c8.png)
#
# ### Método gráfico de Lineweaver-Burk:
#
# Apartir da linearização dos dados obtivemos os valores da nossa função.
#
# ![image.png](attachment:549e87e1-eaf1-4329-ab89-738e001235ad.png)
#
# Fazendo os seguintes cálculos obtivemos o seguinte resultado.
#
# ![image.png](attachment:7ed5ffdd-ec60-44d2-aaef-8aa55ea8b352.png)
# ![image.png](attachment:0c9bfd99-0152-44c2-8127-17a51de5c31b.png)
#
# ![image.png](attachment:4166546b-3fb6-432c-8d42-700e7337def7.png)
#
# Para confirmação foi feito o **Método de Hanes**.
#
# - Gráfico:
#
# ![image.png](attachment:904db420-26a2-47e1-b079-8bf0cc9d6b29.png)
#
# e o seguinte resultado:
#
# ![image.png](attachment:4148c5dd-876e-420d-8f23-23e41fe208b4.png)
# ![image.png](attachment:fdc4788c-26ec-483c-84c6-dcc614a07563.png)
#
# ![image.png](attachment:ced3d772-1d04-4124-9746-9a7b7175f114.png)
