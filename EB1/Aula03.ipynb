# %% [markdown]
# <h1 align="center">Aula 3</h1>

# %% [markdown]
# ---

# %% [markdown]
# <h4 align="center" style="color:gray">Enzimas e Atividade Enzimática</h4>

# %% [markdown]
# ---

# %% [markdown]
# <h3 align="left" style="color:black">Enzimas: </h3>
# Enzimas são moléculas ou proteínas (formada por aminoácidos) que atuam como catalisadores de reações específicas.

# %% [markdown]
# #### Características:
# - Apresentam elevada massa molar.
# - Apresentam poder catalítico muito maior do que catalisadores sintéticos
# - Aceleram a taxa de reação no sentido do seu equilíbrio
# - Não alteram o estado final (equilíbrio termodinâmico) de um dado sistema  químico
# - Participam da reação, mas ao final não têm sua concentração alterada
#
# ![image.png](attachment:74b7cd05-92cc-4eca-8f10-e032cced615f.png)
#
# - Reduzem a energia de ativação (barreira energética a ser vencida para que o reagente se transforme em produto).
#
# Exemplo:
#
# ![image.png](attachment:17739957-85b4-417d-a704-299701675990.png)

# %% [markdown]
# ---

# %% [markdown]
# <h3 align="left" style="color:black">Sítio Catalítico</h3>

# %% [markdown]
# ---

# %% [markdown]
# **Centro ativo** ou **sítio catalítico** de uma enzima é a porção da molécula onde ocorre a atividade catalítica.
#
# #### ALGUMAS CARACTERÍSTICAS DOS SÍTIOS ATIVOS
# - O sítio ativo é uma fenda ou fissura na estrutura da molécula da enzima;
# - O sítio ativo tem conformação tridimensional;
# - O substrato é ligado à enzima através de múltiplas forças fracas;
# - Resíduos de aminoácidos capazes de interagir com o substrato e formação do produto;
#
# ![image.png](attachment:08bb6bab-45e8-42f2-afd9-1f4a3229c85f.png)
#
# Componente químico adicional necessário para a função:
# - ``Cofator:`` íons inorgânicos
# - ``Coenzima:`` moléculas orgânicas complexas
# - ``Se liga muito firmemente ou covalentemente:`` grupo prostético.
# - ``Proteína``: apoenzima ou apoproteína.
# - ``holoenzima`` enzima completa: Proteína + Cofator
#
# ![image.png](attachment:d394f1c1-f80b-40f6-87b2-b169d5005201.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Teoria da Colisão
#
# Todos os átomos, íons e moléculas estão em constante movimento e portanto colidindo constantemente. Assim a energia transferida pelas partículas na colisão pode desorganizar suas estruturas eletrônicas o suficiente para que as ligações químicas sejam quebradas ou novas ligações se formem.

# %% [markdown]
# ---

# %% [markdown]
# ### Obtenção:
#
# ![image.png](attachment:c17c1ae0-dc0c-472b-a309-2d62256b85c1.png)
#
# #### Fungos:
# Os fungos convencionais secretam diversas proteínas, assim:
# - ``Implicação:`` dificuldade em processos de purificação;
# - ``Estratégia utilizada:`` Biologia molecular – eliminação de genes que expressão proteínas indesejadas;
# - ``Condição ideal:`` clonar o gene e expressá-lo em cepas com baixo background de proteínas indesejadas.

# %% [markdown]
# ---

# %% [markdown]
# ### Fermentação:
# é um processo natural em que matérias primas orgânicas complexas são transformadas em substâncias mais simples.
# É utilizada sob ação de fungos (leveduras) e bactérias.
# #### Tipos:
#
# - **Fermentação submersa (FS):** ocorre em meio com presença de água livre e normalmente com substratos solúveis.
#
# - **Fermentação em meios semisólido ou estado sólido (FMSS):** é definida como um processo fermentativo que ocorre na quase ausência de água livre, onde o crescimento microbiano e a formação de produtos ocorrem na superfície de substratos sólidos.

# %% [markdown]
# ### Classificação:
# - Adição do sufixo **ASE** ao nome do substrato.
#     - Ex: urease; amilases;
# - Adição do sufixo ASE ao tipo de reação catalisada.
#     - Ex: álcool desidrogenase; glicose oxidase;
# - Nome trivial.
#     - Ex: pepsina; tripsina; catalase; papaína;
# - Nomes recomendados pela comissão internacional em enzimas.
#
# Cada enzima descrita recebe um número de classificação, conhecido por “E.C.”, que é composto por 4 dígitos:
# 1. Classe
# 2. Sub-classe dentro da classe
# 3. Grupos químicos específicos que participam da reação.
# 4. Aenzima, propriamente dita
#
# ![image.png](attachment:6ad23f89-f3ab-4423-acd0-a921b6620dbb.png)
