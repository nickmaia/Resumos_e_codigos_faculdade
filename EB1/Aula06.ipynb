# %% [markdown]
# ![image.png](attachment:6a15c570-49b1-45aa-bfd3-52119cb11fef.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Resposta:
# ### Método Linewave-Burk
#
# ![image.png](attachment:9835bcb2-199d-46e3-be58-cbe0fbe02937.png)
#
# ### Gráfico
#
# ![image.png](attachment:725b2c66-7094-4675-b3e8-7c94104d04f6.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:bbffc538-261f-4b3e-ace1-74cad825aa4f.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Resposta:
# ### KA:
#
# ![image.png](attachment:5bd950d0-83b4-4c2e-9c78-9b27a8e9aae1.png)
#
# ![image.png](attachment:6d61b214-8d2c-4938-8ae2-17b80e574dd4.png)
#
# ### KB:
#
# ![image.png](attachment:7fad6283-55e3-4e27-a0c5-cb76b7edc6d2.png)
#
# ![image.png](attachment:ea88bdb8-4780-495c-af7c-2bf27a5514fd.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:ff494513-790d-400c-91bf-8189b71885fa.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Resposta:

# %% [markdown]
# ---
