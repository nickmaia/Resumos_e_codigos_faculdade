# %% [markdown]
# ---

# %% [markdown]
# <h2 align="center" style="color:gray">Revisão: Reatores ideais</h2>

# %% [markdown]
# ---

# %% [markdown]
# ### Balanço de massa:
# ![image.png](attachment:8b0a1e51-69d2-4beb-8ee1-fb69622073a7.png)
# ![image.png](attachment:4ccdcebf-37cd-4c67-a214-9c7c4162596d.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Tipos de Reatores:
# - Batelada
# - Contínuos
# - CSTR - Reator Contínuo de Tanque Agitado
# - PFR - Reator com escoamento Empistonado

# %% [markdown]
# ---

# %% [markdown]
# ### Características importantes de cada reator:

# %% [markdown]
# ---

# %% [markdown]
# #### Balanços:
# - ``CSTR:``
#
# ![image.png](attachment:2478ad03-37ae-4e33-9e7e-66794e5ff842.png)
#
# - ``PFR:``
#
# ![image.png](attachment:cbb9d55f-357a-40b7-a2fc-5c4964738281.png)
#
# - ``PBR:``
#
# ![image.png](attachment:93bd5589-257e-483d-9096-2b17b1b9615b.png)
# ![image.png](attachment:f4e3852e-02a3-4e78-8d2d-2300e1cc1c42.png)
#
# - ``Batelada:``
#
# ![image.png](attachment:2ca17e65-d7a1-40ee-bdc3-ab7d78f82b44.png)
# ![image.png](attachment:93f51f42-d9c0-47c8-8f46-fb691e606271.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 01:
# Á temperatura de 649°C o vapor de fosfina se decompõe  como se segue,
#
#     4PH3 -> P4 + 6H2
#
# Para uma alimentação de 2/3 de fosfina e 1/3 inerte molar, qual é a capacidade necessária de um PFR, operando a 649 °C e 11,4 atm, para converter 75% de 10 mols de fosfina/h?
#
# -r fosfina = 10 * C fosfina (mol/l.h)
#
# ![image.png](attachment:7a8e4948-c1d3-4532-a450-6cd9ff55e157.png)
# ![image.png](attachment:e3ddc39d-a146-4f60-89a5-357804e3f779.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 02:
#
# Dada a equação estequiométrica a seguir:
#
#     A -> B + C + 2D
# E a taxa da reação:
#
# ![image.png](attachment:a23968b1-738b-4c70-a74d-db006e562d5d.png)
#
# O valor de K é de 8,6 h-1 e o valor de Ka é de 0,5 L/mol. A alimentação do CSTR é uma mistura de A e um inerte I. A concentração de A na alimentação Cao é igual a 0,75 mol/L. A vazão volumétrica vo é de 1000 L/h.
#
# a) Qual volume do reator é necessário para que a taxa líquia de D seja de no mínimo 1200 mols/h?
#
# b) Calcule a mesma situação para o PFR?
#
#
# ### Resposta:
#
# ![image.png](attachment:37fe9575-1100-4f32-953b-abd62233ba9f.png)
# ![image.png](attachment:c93e8205-834c-416a-a0a2-1f0c87de11b3.png)
# ![image.png](attachment:96ab33fb-78da-4bb6-9d95-9646f709e654.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 03:
#
# Uma enzima especifica atua como catalisador na fermentaçãoo do reagente A. Para uma dada concentração de enzima na corrente aquosa de entrada 25 L/min, encontre o volume necessário do reator CSTR para converter 95% de A (Cao = 1 mol/L) a cinética da fermentação:
#
# Reação:
#
#     A -> R
#
# Taxa da reação:
#
# ![image.png](attachment:15ebbb1d-b987-4eaa-91f0-8c9a28816a46.png)
#
#
# ### Resposta:
#
# ![image.png](attachment:b6bf909c-b9e1-4963-8ddc-7d06f574ff93.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Associação de Reatores:
#
# ![image.png](attachment:033b5a71-52ec-4797-990c-ef09a3fcee53.png)
#
# - FA1 = FA0 (1-X1)
# - FA2 = FA0 (1-X2)
# - FA3 = FA0 (1-X3)
#
# ![image.png](attachment:2030cbc4-dd8c-45aa-b201-771018bdc6da.png)
# ![image.png](attachment:4398bb91-3605-4edd-aa91-68242320e1b3.png)
# ![image.png](attachment:7b88b41c-e91b-42a1-998e-c7815464c3c5.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 04:
# Uma reação de 1° ordem (A -> B) está ocorrendo em fase gasosa a P = 2 atm e T = 400 K. O sistema é alimentado com uma vazão volumétrica de 7 L/s e a mistura contém 80 mols de A e 20% de inerte. Calcule o volume do reator para se converter 85% de A, se o sistema em questão é:
#
# ***Obs:*** A concentração do reagente reduz á metade em 1000 s.
#
# a) CSTR
#
# b) PFR
#
# c) PFR -> CSTR (Volumes iguais)
#
# d) CSRT -> PFR (Volumes iguais)
#
#
# ### Resposta:
#
# ![image.png](attachment:b31f9a2f-1b03-4cc9-9691-79348b2b2049.png)
# ![image.png](attachment:8e5f38cf-46ca-45f1-824e-6756785aa81f.png)
# ![image.png](attachment:052a44d2-03bb-42a8-9398-29b956735866.png)
# ![image.png](attachment:eef98060-709f-4031-b140-b203193acd8d.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Reatores em Paralelo
#
# ![image.png](attachment:c2d87cf8-68fe-4f5e-a2bd-feb0caa51a4a.png)
#
# Balanço no ponto final(saída)
#
#     Q4*X4 + Q6*X5 + Q6*X6 = QT*XF

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 05:
# Uma reação em fase liquida A -> B está ocorrendo em um sistema de reatores em paralelo. A reação é de 1° ordem sendo Cao= 1 mol/L. A alimentação de A é de 170 mols/min e deseja-se uma conversão de no mínimo de 70%.
#
# a) Determine o número de CSTR de 700L
#
# b) determine o numero de PFR de 700L
#
# c) Qual a produção alcançada com 3 reatores em 700 L (2 CSTR e 1 PFR)?
#
# oBS: Para o levantamento cinético, considerando-se a concentração inicial de A igual a 20 mols/L, após 178 s a concentração atinge o valor igual a 17,8 mol/L
#
# ### Resposta:
# ![image.png](attachment:da7508ea-8042-42bb-9f9b-6790c5c4af59.png)
# ![image.png](attachment:09609325-050c-4ac4-9608-59f6220baf4b.png)
# ![image.png](attachment:0d7123bb-c746-4864-9507-a1a81ca0d29c.png)
# ![image.png](attachment:2185da17-21e0-4a3b-ac9a-102fdbefd029.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 06:
# A reação de oxidação de SO2 a SO3 está ocorrendo em fase gasosa em um CSTR. A pressão é de 1485 kPa e T = 227°C mantidos constantes. A mistura reacional é de 28% de SO2 e 72% de ar. Considere a vazão inicial igual a 100 L/min.
#
# a) Para um reator CSTR de 5000L qual será a conversão obtida?
#
# b) Calcule a composição dos reagentes e produtos para esta condição.
#
# Obs: Considere a reação elementar e K = 0,01 L^(1/2)/mol^(1/2)*min
#
# ### Resposta:
#
# ![image.png](attachment:b2a1e0c0-f091-4e20-aa4a-ffca5242066f.png)
# ![image.png](attachment:48480eeb-18f6-4e75-85f3-024dbdb406f0.png)
# ![image.png](attachment:858279cf-5e7e-42d8-ae9a-632ea9ddeeac.png)

# %% [markdown]
# ---

# %% [markdown]
# #### Exercicio 07:
# Para o sistema: A -> B
# Sabe-se que em 143 s, 50% da substancia se decompôe. A concentração inicial de A foi considerada igual a 0,06 m e que esta reação segue uma lei cinética de 2° ordem.
#
# a) com base nessas informações encontre o tempo de residência necessário para o sistema, considerando um CSTR e um PFR ideal para uma conversão de 70%.
#
# b) Encontre o número de Damkohler para o sistema considerando os dois reatores calculados na letra a.
#
# ### Resposta:
#
# ![image.png](attachment:1388585e-5e09-4372-b654-a8f314bcb3e8.png)
# ![image.png](attachment:47ceefbe-3ce9-439f-8a2a-49bc53e93969.png)
# ![image.png](attachment:fbe26b1c-1f5a-4c50-92e9-96a39bca4851.png)
# ![image.png](attachment:e625d6da-aa2c-4a8c-80b9-2c1bd5ecf128.png)

# %% [markdown]
# ---
